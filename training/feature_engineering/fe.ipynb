# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.preprocessing import OneHotEncoder

# %%
anime_db = pd.read_csv("../../data/raw/anime.csv")
ratings_db = pd.read_csv("../../data/raw/rating.csv")

# %%
anime_db.rename(columns= {"rating": "anime_avg_rating", "members": "anime_members", "episodes": "anime_episodes"}, inplace=True)
anime_db["genre"] = anime_db["genre"].str.split(", ", n= 1, expand=True)[0]
anime_db.dropna(subset=["anime_avg_rating", "genre"], inplace=True)
anime_db["anime_episodes"] = anime_db["anime_episodes"].apply(lambda x: np.nan if x == "Unknown" else int(x))

# %%
avg_impute_episodes = int(round(anime_db[anime_db["type"] == "TV" ]["anime_episodes"].mean(),0))
avg_impute_episodes
# Out:
# 36

# %%
anime_db['anime_episodes'] = anime_db['anime_episodes'].fillna(avg_impute_episodes).astype(int)

# %%
anime_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12017 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   anime_id          12017 non-null  int64
#  1   name              12017 non-null  object
#  2   genre             12017 non-null  object
#  3   type              12017 non-null  object
#  4   anime_episodes    12017 non-null  int64
#  5   anime_avg_rating  12017 non-null  float64
#  6   anime_members     12017 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 751.1+ KB

# %%
ratings_db_full = ratings_db[ratings_db["rating"] != -1].merge(anime_db.drop("name", axis=1), on="anime_id")
ratings_db_full
# Out:
#          user_id  anime_id  rating      genre     type  anime_episodes  \
# 0              1      8074      10     Action       TV              12
# 1              3      8074       6     Action       TV              12
# 2              5      8074       2     Action       TV              12
# 3             12      8074       6     Action       TV              12
# 4             14      8074       6     Action       TV              12
# ...          ...       ...     ...        ...      ...             ...
# 6337141    69964     23585       7  Adventure  Special               2
# 6337142    69964     33659       6     Comedy  Special               1
# 6337143    72800     30738       4  Adventure    Movie               1
# 6337144    73135      8723       5     Comedy      OVA               4
# 6337145    73188      8749       6     Comedy  Special               1
#
#          anime_avg_rating  anime_members
# 0                    7.46         535892
# 1                    7.46         535892
# 2                    7.46         535892
# 3                    7.46         535892
# 4                    7.46         535892
# ...                   ...            ...
# 6337141              6.14            138
# 6337142              5.15            444
# 6337143              5.55            185
# 6337144              5.84            264
# 6337145              4.45            124
#
# [6337146 rows x 8 columns]

# %%
watched_animes = ratings_db.groupby("user_id").count().rename(columns={"anime_id": "user_watched_animes"})["user_watched_animes"].reset_index()

# %%
aggregated_user_features = ratings_db_full[ratings_db_full["rating"] != -1 ].groupby("user_id").agg({ "rating": ["mean"], "anime_episodes": ["sum"], "genre": [pd.Series.mode]}).reset_index()

# %%
aggregated_user_features.columns = aggregated_user_features.columns.droplevel()
aggregated_user_features.columns = ["user_id", "user_avg_rating", "user_watched_episodes", "user_favorite_genre"]
user_features = aggregated_user_features.merge(watched_animes, on="user_id")

# %%
full_db = ratings_db_full.merge(user_features, how="left", on="user_id")

# %%
full_db["user_avg_episodes"] = full_db["user_watched_episodes"] / full_db["user_watched_animes"]
full_db
# Out:
#          user_id  anime_id  rating      genre     type  anime_episodes  \
# 0              1      8074      10     Action       TV              12
# 1              3      8074       6     Action       TV              12
# 2              5      8074       2     Action       TV              12
# 3             12      8074       6     Action       TV              12
# 4             14      8074       6     Action       TV              12
# ...          ...       ...     ...        ...      ...             ...
# 6337141    69964     23585       7  Adventure  Special               2
# 6337142    69964     33659       6     Comedy  Special               1
# 6337143    72800     30738       4  Adventure    Movie               1
# 6337144    73135      8723       5     Comedy      OVA               4
# 6337145    73188      8749       6     Comedy  Special               1
#
#          anime_avg_rating  anime_members  user_avg_rating  \
# 0                    7.46         535892        10.000000
# 1                    7.46         535892         7.565217
# 2                    7.46         535892         4.355120
# 3                    7.46         535892         8.818182
# 4                    7.46         535892         7.195122
# ...                   ...            ...              ...
# 6337141              6.14            138         7.891859
# 6337142              5.15            444         7.891859
# 6337143              5.55            185         5.930159
# 6337144              5.84            264         5.710953
# 6337145              4.45            124         7.001585
#
#          user_watched_episodes user_favorite_genre  user_watched_animes  \
# 0                           61              Action                  153
# 1                         2874              Action                   94
# 2                        10047              Comedy                  467
# 3                         1121              Action                   22
# 4                         1638              Comedy                  123
# ...                        ...                 ...                  ...
# 6337141                  16013              Action                  825
# 6337142                  16013              Action                  825
# 6337143                   2121              Action                  315
# 6337144                  12148              Action                  986
# 6337145                   3056              Comedy                  861
#
#          user_avg_episodes
# 0                 0.398693
# 1                30.574468
# 2                21.513919
# 3                50.954545
# 4                13.317073
# ...                    ...
# 6337141          19.409697
# 6337142          19.409697
# 6337143           6.733333
# 6337144          12.320487
# 6337145           3.549361
#
# [6337146 rows x 13 columns]

# %%
# Out:
#          user_id  anime_id  rating      genre   type  anime_episodes  \
# 314         1000      8074       9     Action     TV              12
# 32109       1000     11757       9     Action     TV              25
# 75574       1000        20       9     Action     TV             220
# 106193      1000       199      10  Adventure  Movie               1
# 196852      1000      1535      10    Mystery     TV              37
# 258230      1000      3588       7     Action     TV              51
# 696588      1000        30       9     Action     TV              26
# 711536      1000        45       8     Action     TV              94
# 859238      1000       269      10     Action     TV             366
# 1144500     1000      4224       8     Comedy     TV              25
# 1270635     1000      6512       7     Comedy     TV              12
# 1656193     1000     12445      10     Horror     TV              12
# 1705120     1000     13759       7     Comedy     TV              24
# 1723378     1000     14227      10     Comedy     TV              13
# 2200205     1000        31       9      Drama  Movie               1
# 2204594     1000        32       9   Dementia  Movie               1
# 2279416     1000       530       9     Demons     TV              46
# 2366570     1000      2167      10     Comedy     TV              23
# 2443792     1000      4181       8      Drama     TV              24
# 2821553     1000       120       9     Comedy     TV              26
# 2837418     1000       164      10     Action  Movie               1
# 2867477     1000       431      10  Adventure  Movie               1
# 2908515     1000       523      10  Adventure  Movie               1
# 2947698     1000       790       8    Mystery     TV              23
# 2954475     1000       853       8     Comedy     TV              26
# 3083048     1000      1562       6     Comedy     TV              25
# 3254210     1000      1222       7      Drama     TV              26
# 3276054     1000       226      10     Action     TV              13
# 3396044     1000      2476       4      Drama     TV              12
# 3721810     1000       317       8     Action  Movie               1
# 3733301     1000      3457       8      Drama     TV              13
# 3951822     1000      7054      10     Comedy     TV              26
# 4032451     1000      1726       9     Action     TV              12
# 4143417     1000      3470       6     Comedy     TV              24
# 4286110     1000     14289      10    Romance     TV              13
# 4385077     1000      4752       8      Drama     TV              13
# 4507231     1000      1579       8     Comedy     TV              25
# 4555547     1000      6045       6    Romance     TV              25
# 4570509     1000      9656       6    Romance     TV              12
# 4964458     1000       957       6  Adventure     TV              39
# 5529184     1000       426       7     Action    OVA               4
#
#          avg_anime_rating  anime_members  user_avg_rating  \
# 314                  7.46         535892         8.341463
# 32109                7.83         893100         8.341463
# 75574                7.81         683297         8.341463
# 106193               8.93         466254         8.341463
# 196852               8.71        1013917         8.341463
# 258230               8.08         580184         8.341463
# 696588               8.32         461946         8.341463
# 711536               8.43         218928         8.341463
# 859238               7.95         624055         8.341463
# 1144500              8.45         633817         8.341463
# 1270635              7.39         142264         8.341463
# 1656193              7.95         172367         8.341463
# 1705120              8.40         380375         8.341463
# 1723378              7.77         349836         8.341463
# 2200205              7.51         102093         8.341463
# 2204594              8.45         215630         8.341463
# 2279416              7.71         146521         8.341463
# 2366570              8.30         566690         8.341463
# 2443792              9.06         456749         8.341463
# 2821553              7.80         242553         8.341463
# 2837418              8.81         339556         8.341463
# 2867477              8.74         333186         8.341463
# 2908515              8.48         271484         8.341463
# 2947698              8.03         265005         8.341463
# 2954475              8.39         422271         8.341463
# 3083048              7.89          92088         8.341463
# 3254210              7.54         125051         8.341463
# 3276054              7.85         623511         8.341463
# 3396044              6.17         279183         8.341463
# 3721810              7.94         138659         8.341463
# 3733301              7.40         286826         8.341463
# 3951822              8.26         391628         8.341463
# 4032451              7.15         166398         8.341463
# 4143417              7.78         173603         8.341463
# 4286110              7.71         233410         8.341463
# 4385077              7.53         198492         8.341463
# 4507231              7.69          63134         8.341463
# 4555547              8.19         309339         8.341463
# 4570509              8.17         171866         8.341463
# 4964458              8.06          50951         8.341463
# 5529184              6.25          10325         8.341463
#
#          user_watched_episodes user_favorite_genre  user_watched_animes  \
# 314                       1374              Action                   41
# 32109                     1374              Action                   41
# 75574                     1374              Action                   41
# 106193                    1374              Action                   41
# 196852                    1374              Action                   41
# 258230                    1374              Action                   41
# 696588                    1374              Action                   41
# 711536                    1374              Action                   41
# 859238                    1374              Action                   41
# 1144500                   1374              Action                   41
# 1270635                   1374              Action                   41
# 1656193                   1374              Action                   41
# 1705120                   1374              Action                   41
# 1723378                   1374              Action                   41
# 2200205                   1374              Action                   41
# 2204594                   1374              Action                   41
# 2279416                   1374              Action                   41
# 2366570                   1374              Action                   41
# 2443792                   1374              Action                   41
# 2821553                   1374              Action                   41
# 2837418                   1374              Action                   41
# 2867477                   1374              Action                   41
# 2908515                   1374              Action                   41
# 2947698                   1374              Action                   41
# 2954475                   1374              Action                   41
# 3083048                   1374              Action                   41
# 3254210                   1374              Action                   41
# 3276054                   1374              Action                   41
# 3396044                   1374              Action                   41
# 3721810                   1374              Action                   41
# 3733301                   1374              Action                   41
# 3951822                   1374              Action                   41
# 4032451                   1374              Action                   41
# 4143417                   1374              Action                   41
# 4286110                   1374              Action                   41
# 4385077                   1374              Action                   41
# 4507231                   1374              Action                   41
# 4555547                   1374              Action                   41
# 4570509                   1374              Action                   41
# 4964458                   1374              Action                   41
# 5529184                   1374              Action                   41
#
#          user_avg_episodes
# 314              33.512195
# 32109            33.512195
# 75574            33.512195
# 106193           33.512195
# 196852           33.512195
# 258230           33.512195
# 696588           33.512195
# 711536           33.512195
# 859238           33.512195
# 1144500          33.512195
# 1270635          33.512195
# 1656193          33.512195
# 1705120          33.512195
# 1723378          33.512195
# 2200205          33.512195
# 2204594          33.512195
# 2279416          33.512195
# 2366570          33.512195
# 2443792          33.512195
# 2821553          33.512195
# 2837418          33.512195
# 2867477          33.512195
# 2908515          33.512195
# 2947698          33.512195
# 2954475          33.512195
# 3083048          33.512195
# 3254210          33.512195
# 3276054          33.512195
# 3396044          33.512195
# 3721810          33.512195
# 3733301          33.512195
# 3951822          33.512195
# 4032451          33.512195
# 4143417          33.512195
# 4286110          33.512195
# 4385077          33.512195
# 4507231          33.512195
# 4555547          33.512195
# 4570509          33.512195
# 4964458          33.512195
# 5529184          33.512195
